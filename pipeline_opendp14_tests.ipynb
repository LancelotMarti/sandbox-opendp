# %%
# !pip install opendp==0.14.1
# !pip install polars==1.32.0
# Out:
# Requirement already satisfied: opendp==0.14.1 in /opt/python/lib/python3.13/site-packages (0.14.1)
# Requirement already satisfied: deprecated in /opt/python/lib/python3.13/site-packages (from opendp==0.14.1) (1.3.1)
# Requirement already satisfied: wrapt<3,>=1.10 in /opt/python/lib/python3.13/site-packages (from deprecated->opendp==0.14.1) (2.1.0)
# Requirement already satisfied: polars==1.32.0 in /opt/python/lib/python3.13/site-packages (1.32.0)

# %%
import numpy as np
import polars as pl
import matplotlib.pyplot as plt
import opendp.prelude as dp
import polars as pl

dp.enable_features("contrib")

# %%
dummy_lf = pl.scan_csv('example_pipeline_new.csv', try_parse_dates=True)
# random context
def create_context():

    custom_context =  dp.Context.compositor(
        data=pl.scan_csv('example_pipeline_new.csv', try_parse_dates=True),
        privacy_unit = dp.unit_of(contributions=1),
        privacy_loss=dp.loss_of(rho=10.0, delta=1e-6),
        split_evenly_over=1,
        margins=[
            dp.polars.Margin(
                max_length=1000,
                invariant="lengths"
            ),
            dp.polars.Margin(
                by=["patient_id"],
            ),
        ]
    )

    return custom_context

# %% [markdown]
# # Pipeline combination

# %%
dummy_lf.collect()
# Out:
# shape: (15_100, 11)
# ┌────────────┬─────────┬──────┬──────────┬───┬─────┬────────────┬───────────┬────────────────┐
# │ patient_id ┆ case_id ┆ year ┆ hospital ┆ … ┆ sex ┆ diagnostic ┆ treatment ┆ treatment_date │
# │ ---        ┆ ---     ┆ ---  ┆ ---      ┆   ┆ --- ┆ ---        ┆ ---       ┆ ---            │
# │ i64        ┆ i64     ┆ i64  ┆ f64      ┆   ┆ i64 ┆ str        ┆ str       ┆ str            │
# ╞════════════╪═════════╪══════╪══════════╪═══╪═════╪════════════╪═══════════╪════════════════╡
# │ 5          ┆ 56      ┆ 2022 ┆ 22.0     ┆ … ┆ 2   ┆ 4WfjG      ┆ null      ┆ null           │
# │ 29         ┆ 42      ┆ 2022 ┆ 59.0     ┆ … ┆ 2   ┆ 4wh        ┆ null      ┆ null           │
# │ 85         ┆ 69      ┆ 2005 ┆ 25.0     ┆ … ┆ 1   ┆ 94Sw       ┆ null      ┆ null           │
# │ 70         ┆ 91      ┆ 2003 ┆ 44.0     ┆ … ┆ 2   ┆ GkT        ┆ null      ┆ null           │
# │ 81         ┆ 33      ┆ 2005 ┆ 23.0     ┆ … ┆ 1   ┆ dv         ┆ null      ┆ null           │
# │ …          ┆ …       ┆ …    ┆ …        ┆ … ┆ …   ┆ …          ┆ …         ┆ …              │
# │ 29         ┆ 99      ┆ 2003 ┆ 94.0     ┆ … ┆ 1   ┆ null       ┆ ciHC1     ┆ 2014-10-06     │
# │ 2          ┆ 32      ┆ 2015 ┆ 42.0     ┆ … ┆ 2   ┆ null       ┆ ETb       ┆ 2023-09-03     │
# │ 90         ┆ 48      ┆ 2020 ┆ 12.0     ┆ … ┆ 1   ┆ null       ┆ null      ┆ 2013-02-17     │
# │ 74         ┆ 23      ┆ 2020 ┆ 12.0     ┆ … ┆ 1   ┆ null       ┆ 18nL      ┆ 2018-07-13     │
# │ 81         ┆ 83      ┆ 2025 ┆ null     ┆ … ┆ 2   ┆ null       ┆ wC5       ┆ 2015-05-02     │
# └────────────┴─────────┴──────┴──────────┴───┴─────┴────────────┴───────────┴────────────────┘

# %% [markdown]
# ## With Polars

# %%
# Get patient with diagnostic C18
plan_1 = (
    dummy_lf.filter(pl.col("diagnostic")=="C18")
    .group_by(["patient_id"])
    .agg([
        pl.len()
    ])
)

# Get patient that had treatment xx
plan_2 = (
    dummy_lf.filter(pl.col("treatment")=="xx")
    .group_by(["patient_id"])
    .agg([
        pl.len()
    ])
)

# join both pipeline
plan_join = (
    plan_1.join(plan_2, on="patient_id")
    .select(pl.len())
)

# collect result
plan_join.collect().item()
# Out:
# 15

# %% [markdown]
# ## With OpenDP

# %%
context1 = create_context()
plan_dp_1 = (
    context1.query().filter(pl.col("diagnostic")=="C18")
    .group_by(["patient_id"])
    .agg([
        pl.len()
    ])
)
# Out:
# rho should be less than or equal to 0.5, and is typically less than or equal to 0.25

# %%
context2 = create_context()
plan_dp_2 = (
    context2.query().filter(pl.col("treatment")=="xx")
    .group_by(["patient_id"])
    .agg([
        pl.len()
    ])
    .join(plan_dp_1, on="patient_id")
    .select(pl.col("patient_id")).dp.len()
)
# Out:
# rho should be less than or equal to 0.5, and is typically less than or equal to 0.25
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 8
#       1 context2 = create_context()
#       2 plan_dp_2 = (
#       3     context2.query().filter(pl.col("treatment")=="xx")
#       4     .group_by(["patient_id"])
#       5     .agg([
#       6         pl.len()
#       7     ])
# ----> 8     .join(plan_dp_1, on="patient_id")
#       9     .select(pl.col("patient_id")).dp.len()
#      10 )
#
# File /opt/python/lib/python3.13/site-packages/opendp/extras/polars/__init__.py:710, in LazyFrameQuery.__getattribute__.<locals>._wrap(*args, **kwargs)
#     709 def _wrap(*args, **kwargs):
# --> 710     out = attr(*args, **kwargs)
#     712     if pl is not None:
#     713         # re-wrap any lazy outputs to keep the conveniences afforded by this class
#     714         if isinstance(out, pl.lazyframe.frame.LazyFrame):
#
# File /opt/python/lib/python3.13/site-packages/polars/_utils/deprecation.py:128, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     123 @wraps(function)
#     124 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#     125     _rename_keyword_argument(
#     126         old_name, new_name, kwargs, function.__qualname__, version
#     127     )
# --> 128     return function(*args, **kwargs)
#
# File /opt/python/lib/python3.13/site-packages/polars/lazyframe/frame.py:5440, in LazyFrame.join(self, other, on, how, left_on, right_on, suffix, validate, nulls_equal, coalesce, maintain_order, allow_parallel, force_parallel)
#    5227 @deprecate_renamed_parameter("join_nulls", "nulls_equal", version="1.24")
#    5228 def join(
#    5229     self,
#    (...)   5242     force_parallel: bool = False,
#    5243 ) -> LazyFrame:
#    5244     """
#    5245     Add a join operation to the Logical Plan.
#    5246
#    (...)   5438     └─────┴─────┴─────┴───────┴───────────┘
#    5439     """
# -> 5440     require_same_type(self, other)
#    5442     if maintain_order is None:
#    5443         maintain_order = "none"
#
# File /opt/python/lib/python3.13/site-packages/polars/_utils/various.py:766, in require_same_type(current, other)
#     761 if not isinstance(other, type(current)) and not isinstance(current, type(other)):
#     762     msg = (
#     763         f"expected `other` to be a {qualified_type_name(current)!r}, "
#     764         f"not {qualified_type_name(other)!r}"
#     765     )
# --> 766     raise TypeError(msg)
#
# TypeError: expected `other` to be a 'LazyFrame', not 'opendp.extras.polars._wrap'

# %% [markdown]
# # with_columns (``.any()`` / ``.over()``)

# %% [markdown]
# ## Polars

# %%
plan = (
    dummy_lf
    # Add per-patient flags indicating whether they ever had diagnostic C18 and treatment xx
    .with_columns(has_c18 = (pl.col("diagnostic") == "C18").any().over("patient_id"))
    .with_columns(has_xx = ((pl.col("treatment")=="xx").any().over("patient_id")))
    # Filter patients with both conditions
    .filter(pl.col("has_c18") & pl.col("has_xx"))
    # Count total patient (unique) with both cases
    .select(pl.col("patient_id").n_unique())

)

plan.collect()
# Out:
# shape: (1, 1)
# ┌────────────┐
# │ patient_id │
# │ ---        │
# │ u32        │
# ╞════════════╡
# │ 15         │
# └────────────┘

# %% [markdown]
# ## OpenDP

# %%
# For now, this is not regognised in opendp
# ==> we get an error
context = create_context()
plan_dp = (
    context.query()
    # Add per-patient flags indicating whether they ever had diagnostic C18 and treatment xx
    .with_columns(has_c18 = (pl.col("diagnostic") == "C18").any().over("patient_id"))
    .with_columns(has_xx = ((pl.col("treatment")=="xx").any().over("patient_id")))
    # Filter patients with both conditions
    .filter(pl.col("has_c18") & pl.col("has_xx"))
    # Count total patient (unique) with both cases
    .select(pl.col("patient_id").dp.n_unique())

)
plan_dp.release().collect()
# Out:
# rho should be less than or equal to 0.5, and is typically less than or equal to 0.25
# ---------------------------------------------------------------------------
# OpenDPException                           Traceback (most recent call last)
# Cell In[9], line 15
#       3 context = create_context()
#       4 plan_dp = (
#       5     context.query()
#       6     # Add per-patient flags indicating whether they ever had diagnostic C18 and treatment xx
#    (...)     13
#      14 )
# ---> 15 plan_dp.release().collect()
#
# File /opt/python/lib/python3.13/site-packages/opendp/extras/polars/__init__.py:1001, in LazyFrameQuery.release(self)
#     999 query = object.__getattribute__(self, "_query")
#    1000 resolve = object.__getattribute__(self, "resolve")
# -> 1001 return query._context(resolve())
#
# File /opt/python/lib/python3.13/site-packages/opendp/extras/polars/__init__.py:973, in LazyFrameQuery.resolve(self)
#     969 # when the output measure is δ-approximate, then there are two free parameters to tune
#     970 if getattr(query._output_measure.type, "origin", None) == "Approximate":
#     971     # search for a scale parameter. Solve for epsilon first,
#     972     # setting threshold to u32::MAX so as not to interfere with the search for a suitable scale parameter
# --> 973     scale = binary_search(
#     974         lambda s: _make(s, threshold=2**32 - 1).map(d_in)[0] < d_out[0],  # type: ignore[index]
#     975         T=float,
#     976     )
#     978     # attempt to return without setting a threshold
#     979     try:
#
# File /opt/python/lib/python3.13/site-packages/opendp/mod.py:1490, in binary_search(predicate, bounds, T, return_sign)
#    1439 """Find the closest passing value to the decision boundary of `predicate`.
#    1440
#    1441 If bounds are not passed, conducts an exponential search.
#    (...)   1487 3
#    1488 """
#    1489 if bounds is None:
# -> 1490     bounds = exponential_bounds_search(predicate, T) # type: ignore
#    1492 if bounds is None:
#    1493     raise ValueError("unable to infer bounds")  # pragma: no cover
#
# File /opt/python/lib/python3.13/site-packages/opendp/mod.py:1613, in exponential_bounds_search(predicate, T)
#    1611 if exception_bounds is None:
#    1612     try:
# -> 1613         predicate(center)
#    1614     except Exception as e:
#    1615         # enrich the error message if in Python 3.11+.
#    1616         if hasattr(e, "add_note"):
#
# File /opt/python/lib/python3.13/site-packages/opendp/extras/polars/__init__.py:974, in LazyFrameQuery.resolve.<locals>.<lambda>(s)
#     969 # when the output measure is δ-approximate, then there are two free parameters to tune
#     970 if getattr(query._output_measure.type, "origin", None) == "Approximate":
#     971     # search for a scale parameter. Solve for epsilon first,
#     972     # setting threshold to u32::MAX so as not to interfere with the search for a suitable scale parameter
#     973     scale = binary_search(
# --> 974         lambda s: _make(s, threshold=2**32 - 1).map(d_in)[0] < d_out[0],  # type: ignore[index]
#     975         T=float,
#     976     )
#     978     # attempt to return without setting a threshold
#     979     try:
#
# File /opt/python/lib/python3.13/site-packages/opendp/extras/polars/__init__.py:951, in LazyFrameQuery.resolve.<locals>._make(scale, threshold)
#     950 def _make(scale, threshold=None):
# --> 951     return make_private_lazyframe(
#     952         input_domain=input_domain,
#     953         input_metric=input_metric,
#     954         output_measure=query._output_measure,
#     955         lazyframe=polars_plan,
#     956         global_scale=scale,
#     957         threshold=threshold,
#     958     )
#
# File /opt/python/lib/python3.13/site-packages/opendp/measurements.py:1696, in make_private_lazyframe(input_domain, input_metric, output_measure, lazyframe, global_scale, threshold)
#    1693 lib_function.argtypes = [Domain, Metric, Measure, AnyObjectPtr, AnyObjectPtr, AnyObjectPtr]
#    1694 lib_function.restype = FfiResult
# -> 1696 output = c_to_py(unwrap(lib_function(c_input_domain, c_input_metric, c_output_measure, c_lazyframe, c_global_scale, c_threshold), Measurement))
#    1697 try:
#    1698     output.__opendp_dict__ = {
#    1699         '__function__': 'make_private_lazyframe',
#    1700         '__module__': 'measurements',
#    (...)   1703         },
#    1704     }
#
# File /opt/python/lib/python3.13/site-packages/opendp/_lib.py:337, in unwrap(result, type_)
#     335     if 'polars' in str(message).lower() and pl.__version__ != _EXPECTED_POLARS_VERSION:
#     336         message = f'Installed python polars version ({pl.__version__}) != expected version ({_EXPECTED_POLARS_VERSION}). {message}' # pragma: no cover
# --> 337 raise OpenDPException(variant, message, backtrace)
#
# OpenDPException:
#   MakeTransformation("Expr is not recognized at this time: [(col("diagnostic")) == ("C18")].any().over([col("patient_id")]). If you would like to see this supported, please file an issue.")
# Predicate in binary search always raises an exception. This exception is raised when the predicate is evaluated at 0.0.

# %% [markdown]
# # with_columns (``.min()``)

# %% [markdown]
# ## With Polars

# %%
# Polars: Filter patients that recieved treatment over 15 years
plan_diff = (
    dummy_lf
    .with_columns(age_min = (pl.col("age")).min().over("patient_id"))
    .with_columns(age_max = ((pl.col("age")).max().over("patient_id")))
    .with_columns(age_diff  = (pl.col("age_max")) - (pl.col("age_min")))
    .filter(pl.col("age_diff")>15)
    .select(pl.col("patient_id").n_unique())

)

plan_diff.collect()
# Out:
# shape: (1, 1)
# ┌────────────┐
# │ patient_id │
# │ ---        │
# │ u32        │
# ╞════════════╡
# │ 22         │
# └────────────┘

# %% [markdown]
# ## With OpenDP

# %%
# min/max does not seem to be working with openDP neither (with columns)

context = create_context()
plan_diff_dp = (
    context.query()
    .with_columns(age_min = (pl.col("age")).min().over("patient_id"))
    .with_columns(age_max = ((pl.col("age")).max().over("patient_id")))
    .with_columns(age_diff  = (pl.col("age_max")) - (pl.col("age_min")))
    .filter(pl.col("age_diff")>15)
    .select(pl.col("patient_id").dp.n_unique())

)

plan_diff_dp.release().collect()
# Out:
# rho should be less than or equal to 0.5, and is typically less than or equal to 0.25
# ---------------------------------------------------------------------------
# OpenDPException                           Traceback (most recent call last)
# Cell In[11], line 14
#       3 context = create_context()
#       4 plan_diff_dp = (
#       5     context.query()
#       6     .with_columns(age_min = (pl.col("age")).min().over("patient_id"))
#    (...)     11
#      12 )
# ---> 14 plan_diff_dp.release().collect()
#
# File /opt/python/lib/python3.13/site-packages/opendp/extras/polars/__init__.py:1001, in LazyFrameQuery.release(self)
#     999 query = object.__getattribute__(self, "_query")
#    1000 resolve = object.__getattribute__(self, "resolve")
# -> 1001 return query._context(resolve())
#
# File /opt/python/lib/python3.13/site-packages/opendp/extras/polars/__init__.py:973, in LazyFrameQuery.resolve(self)
#     969 # when the output measure is δ-approximate, then there are two free parameters to tune
#     970 if getattr(query._output_measure.type, "origin", None) == "Approximate":
#     971     # search for a scale parameter. Solve for epsilon first,
#     972     # setting threshold to u32::MAX so as not to interfere with the search for a suitable scale parameter
# --> 973     scale = binary_search(
#     974         lambda s: _make(s, threshold=2**32 - 1).map(d_in)[0] < d_out[0],  # type: ignore[index]
#     975         T=float,
#     976     )
#     978     # attempt to return without setting a threshold
#     979     try:
#
# File /opt/python/lib/python3.13/site-packages/opendp/mod.py:1490, in binary_search(predicate, bounds, T, return_sign)
#    1439 """Find the closest passing value to the decision boundary of `predicate`.
#    1440
#    1441 If bounds are not passed, conducts an exponential search.
#    (...)   1487 3
#    1488 """
#    1489 if bounds is None:
# -> 1490     bounds = exponential_bounds_search(predicate, T) # type: ignore
#    1492 if bounds is None:
#    1493     raise ValueError("unable to infer bounds")  # pragma: no cover
#
# File /opt/python/lib/python3.13/site-packages/opendp/mod.py:1613, in exponential_bounds_search(predicate, T)
#    1611 if exception_bounds is None:
#    1612     try:
# -> 1613         predicate(center)
#    1614     except Exception as e:
#    1615         # enrich the error message if in Python 3.11+.
#    1616         if hasattr(e, "add_note"):
#
# File /opt/python/lib/python3.13/site-packages/opendp/extras/polars/__init__.py:974, in LazyFrameQuery.resolve.<locals>.<lambda>(s)
#     969 # when the output measure is δ-approximate, then there are two free parameters to tune
#     970 if getattr(query._output_measure.type, "origin", None) == "Approximate":
#     971     # search for a scale parameter. Solve for epsilon first,
#     972     # setting threshold to u32::MAX so as not to interfere with the search for a suitable scale parameter
#     973     scale = binary_search(
# --> 974         lambda s: _make(s, threshold=2**32 - 1).map(d_in)[0] < d_out[0],  # type: ignore[index]
#     975         T=float,
#     976     )
#     978     # attempt to return without setting a threshold
#     979     try:
#
# File /opt/python/lib/python3.13/site-packages/opendp/extras/polars/__init__.py:951, in LazyFrameQuery.resolve.<locals>._make(scale, threshold)
#     950 def _make(scale, threshold=None):
# --> 951     return make_private_lazyframe(
#     952         input_domain=input_domain,
#     953         input_metric=input_metric,
#     954         output_measure=query._output_measure,
#     955         lazyframe=polars_plan,
#     956         global_scale=scale,
#     957         threshold=threshold,
#     958     )
#
# File /opt/python/lib/python3.13/site-packages/opendp/measurements.py:1696, in make_private_lazyframe(input_domain, input_metric, output_measure, lazyframe, global_scale, threshold)
#    1693 lib_function.argtypes = [Domain, Metric, Measure, AnyObjectPtr, AnyObjectPtr, AnyObjectPtr]
#    1694 lib_function.restype = FfiResult
# -> 1696 output = c_to_py(unwrap(lib_function(c_input_domain, c_input_metric, c_output_measure, c_lazyframe, c_global_scale, c_threshold), Measurement))
#    1697 try:
#    1698     output.__opendp_dict__ = {
#    1699         '__function__': 'make_private_lazyframe',
#    1700         '__module__': 'measurements',
#    (...)   1703         },
#    1704     }
#
# File /opt/python/lib/python3.13/site-packages/opendp/_lib.py:337, in unwrap(result, type_)
#     335     if 'polars' in str(message).lower() and pl.__version__ != _EXPECTED_POLARS_VERSION:
#     336         message = f'Installed python polars version ({pl.__version__}) != expected version ({_EXPECTED_POLARS_VERSION}). {message}' # pragma: no cover
# --> 337 raise OpenDPException(variant, message, backtrace)
#
# OpenDPException:
#   MakeTransformation("Expr is not recognized at this time: col("age").min().over([col("patient_id")]). If you would like to see this supported, please file an issue.")
# Predicate in binary search always raises an exception. This exception is raised when the predicate is evaluated at 0.0.
